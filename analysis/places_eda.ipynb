# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('analytics_leads_2026-06-13.csv')

# %%
df.head()
# Out:
#        Название     Категория                             Адрес  \
# 0        Грабли  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1  True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2    Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 3          Эссе  Кофейня/Кафе             Никитинская улица, 13
# 4         Му-Му  Кофейня/Кафе  Адрес не указан (см. координаты)
#
#           Телефон                          Сайт/Соцсеть  Сеть/Бренд  \
# 0  +7 495 5450830                     http://grabli.ru/         NaN
# 1  +7 965 1054499  https://www.facebook.com/TrueBurgers         NaN
# 2  +7 969 1123388                  http://pizzamento.ru         NaN
# 3  +7 499 9400564                 https://cafeesse.com/         NaN
# 4  +7 499 2696387              https://www.cafemumu.ru/         NaN
#
#   Потенциал аналитики                                 Обоснование оценки  \
# 0                HIGH  Независимый бизнес с сайтом и телефоном (есть ...
# ...

# %%
df.shape
# Out:
# (1162, 11)

# %%
grouped_category = df.groupby('Категория')['Название'].count()

# %%
grouped_category
# Out:
# Категория
# Кондитерская          92
# Кофейня/Кафе         965
# Пекарня              103
# Цветочный магазин      2
# Name: Название, dtype: int64

# %%
grouped_category.plot(kind='bar')
# Out:
# <Axes: xlabel='Категория'>

# %%
data = df[df['Категория'] != 'Цветочный магазин']

# %%
data_counts = data['Категория'].value_counts()

# %%
data_counts
# Out:
# Категория
# Кофейня/Кафе    965
# Пекарня         103
# Кондитерская     92
# Name: count, dtype: int64

# %%
df
# Out:
#             Название     Категория                             Адрес  \
# 0             Грабли  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1       True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2         Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 3               Эссе  Кофейня/Кафе             Никитинская улица, 13
# 4              Му-Му  Кофейня/Кафе  Адрес не указан (см. координаты)
# ...              ...           ...                               ...
# 1157   Лепим и варим  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1158        Шашлычок  Кофейня/Кафе           проспект Мира, 119 с503
# 1159          Скалка       Пекарня        1-я Останкинская улица, 23
# 1160  Frank by Баста  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1161     Русский чай  Кофейня/Кафе    1-я Останкинская улица, 7А с18
#
#                              Телефон                          Сайт/Соцсеть  \
# ...

# %%
data
# Out:
#             Название     Категория                             Адрес  \
# 0             Грабли  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1       True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2         Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 3               Эссе  Кофейня/Кафе             Никитинская улица, 13
# 4              Му-Му  Кофейня/Кафе  Адрес не указан (см. координаты)
# ...              ...           ...                               ...
# 1157   Лепим и варим  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1158        Шашлычок  Кофейня/Кафе           проспект Мира, 119 с503
# 1159          Скалка       Пекарня        1-я Останкинская улица, 23
# 1160  Frank by Баста  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1161     Русский чай  Кофейня/Кафе    1-я Останкинская улица, 7А с18
#
#                              Телефон                          Сайт/Соцсеть  \
# ...

# %%
unique_numbers = np.array(data['Телефон'].unique())

# %%
unique_numbers.shape
# Out:
# (822,)

# %%
data.shape
# Out:
# (1160, 11)

# %%
clean_data = data.drop_duplicates(subset=['Телефон']).copy()

# %%
clean_data.shape
# Out:
# (822, 11)

# %%
clean_data.head()
# Out:
#        Название     Категория                             Адрес  \
# 0        Грабли  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1  True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2    Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 3          Эссе  Кофейня/Кафе             Никитинская улица, 13
# 4         Му-Му  Кофейня/Кафе  Адрес не указан (см. координаты)
#
#           Телефон                          Сайт/Соцсеть  Сеть/Бренд  \
# 0  +7 495 5450830                     http://grabli.ru/         NaN
# 1  +7 965 1054499  https://www.facebook.com/TrueBurgers         NaN
# 2  +7 969 1123388                  http://pizzamento.ru         NaN
# 3  +7 499 9400564                 https://cafeesse.com/         NaN
# 4  +7 499 2696387              https://www.cafemumu.ru/         NaN
#
#   Потенциал аналитики                                 Обоснование оценки  \
# 0                HIGH  Независимый бизнес с сайтом и телефоном (есть ...
# ...

# %%
clean_data['Is_Mobile'] = clean_data["Телефон"].str.contains(r'\+7\s*9|8\s*9', regex=True, na=False)

# %%
clean_data.shape
# Out:
# (822, 12)

# %%
clean_data['Is_Mobile']
# Out:
# 0       False
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1156     True
# 1157     True
# 1158    False
# 1160     True
# 1161    False
# Name: Is_Mobile, Length: 822, dtype: bool

# %%
clean_data.describe()
# Out:
#        Сеть/Бренд      Широта     Долгота
# count         0.0  822.000000  822.000000
# mean          NaN   55.736863   37.630688
# std           NaN    0.489469    1.427702
# min           NaN   43.226791   30.387496
# 25%           NaN   55.721633   37.537566
# 50%           NaN   55.759602   37.599920
# 75%           NaN   55.786156   37.636645
# max           NaN   59.925323   76.863333

# %%
clean_data.head()
# Out:
#        Название     Категория                             Адрес  \
# 0        Грабли  Кофейня/Кафе  Адрес не указан (см. координаты)
# 1  True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2    Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 3          Эссе  Кофейня/Кафе             Никитинская улица, 13
# 4         Му-Му  Кофейня/Кафе  Адрес не указан (см. координаты)
#
#           Телефон                          Сайт/Соцсеть  Сеть/Бренд  \
# 0  +7 495 5450830                     http://grabli.ru/         NaN
# 1  +7 965 1054499  https://www.facebook.com/TrueBurgers         NaN
# 2  +7 969 1123388                  http://pizzamento.ru         NaN
# 3  +7 499 9400564                 https://cafeesse.com/         NaN
# 4  +7 499 2696387              https://www.cafemumu.ru/         NaN
#
#   Потенциал аналитики                                 Обоснование оценки  \
# 0                HIGH  Независимый бизнес с сайтом и телефоном (есть ...
# ...

# %%
clean_data = clean_data[clean_data['Is_Mobile'] == True]

# %%
clean_data.head()
# Out:
#         Название     Категория                             Адрес  \
# 1   True Burgers  Кофейня/Кафе  Адрес не указан (см. координаты)
# 2     Pizzamento  Кофейня/Кафе  Адрес не указан (см. координаты)
# 7      Алтаргана  Кофейня/Кафе  Адрес не указан (см. координаты)
# 13         Булка       Пекарня  Адрес не указан (см. координаты)
# 14      Карамель  Кофейня/Кафе  Адрес не указан (см. координаты)
#
#                            Телефон                          Сайт/Соцсеть  \
# 1                   +7 965 1054499  https://www.facebook.com/TrueBurgers
# 2                   +7 969 1123388                  http://pizzamento.ru
# 7   +7 499 9755639, +7 915 4924830          https://altargana-moscow.ru/
# 13                  +7 495 2589170             http://www.bulkabakery.ru
# 14                  +7 968 6255655             http://karaoke-karamel.ru
#
#     Сеть/Бренд Потенциал аналитики  \
# 1          NaN                HIGH
# 2          NaN                HIGH
# ...

# %%
clean_data.shape
# Out:
# (465, 12)

# %%
clean_data.to_csv('data_clean.csv', index=False, encoding='utf-8-sig')
